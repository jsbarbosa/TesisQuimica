# %%
import numpy as np
import matplotlib.pyplot as plt

from scipy.signal import medfilt
from scipy.optimize import curve_fit

# %matplotlib
# Out:
# Using matplotlib backend: TkAgg

# %%
def loadData(file_name, start = 100, until = 13100):
    data = np.genfromtxt(file_name, delimiter=",", skip_header = 1)
    ch1 = data[start:until, :2]
    ch2 = data[start:until, 2:4]
    ch3 = data[start:until, 4:6]
    ch1[:, 0] *= 1 / 3600 # horas
    ch2[:, 0] *= 1 / 3600
    ch3[:, 0] *= 1 / 3600
    ch1[:, 1] *= 1000 # mV
    ch2[:, 1] *= 1000
    ch3[:, 1] *= 1000
    return ch1, ch2, ch3

def medianFilter(data, kernel = 1001):
    array = np.zeros((len(data), 2))
    array[:, 0] = data[:, 0] / 3600 # horas
    array[:, 1] = medfilt(data[:, 1], kernel_size = kernel)
    return data

def findZeros(ch1, ch2, ch3):
    y = np.zeros((len(ch1), 3))
    y[:, 0] = ch1[:, 1]
    y[:, 1] = ch2[:, 1]
    y[:, 2] = ch3[:, 1]
    
    y = np.mean(y, axis = 1)
    dy = abs(np.diff(y))
    abs_dy = np.zeros(len(dy) + 1)
    abs_dy[0] = dy[1]
    abs_dy[1:] = dy
    
    
    dy = medfilt(abs_dy, kernel_size = 507)
    pos = (dy > 5e-2)
    dy[pos] = 0.3
    dy[np.logical_not(pos)] = 0
    return abs_dy, dy

def regression(x, y):
    def linear(x, m, b):
        return m*x + b
    
    return curve_fit(linear, x, y)

# %%
ch1, ch2, ch3 = loadData("TemperatureCalibration.csv")

# %%
fig, ax = plt.subplots(figsize = (8, 4.5))

ax.plot(ch1[:, 0], ch1[:, 1], label = "Sensor 1")
ax.plot(ch2[:, 0], ch2[:, 1], label = "Sensor 2")
ax.plot(ch3[:, 0], ch3[:, 1], label = "Sensor 3")
ax.legend()
ax.set_xlabel("Tiempo (horas)")
ax.set_ylabel("Voltaje (mV)")

fig.tight_layout()
plt.show()

# %%
abs_dy, dy = findZeros(ch1, ch2, ch3)
fig, (ax, ax2) = plt.subplots(2, figsize = (8, 4.5))

ax.plot(ch1[:, 0], ch1[:, 1], label = "Sensor 1")
ax.plot(ch2[:, 0], ch2[:, 1], label = "Sensor 2")
ax.plot(ch3[:, 0], ch3[:, 1], label = "Sensor 3")

ax.legend()
ax.set_ylabel("Voltaje (mV)")

ax2.plot(ch1[:, 0], abs_dy)
ax2.plot(ch1[:, 0], dy, label = "Filtrado")
ax2.legend()
ax2.set_xlabel("Tiempo (horas)")
ax2.set_ylabel("$dVoltaje / dt$ (mV / hora)")

fig.tight_layout()
plt.show()

# %%
changes = []
for i in range(1, len(dy)):
    diff = dy[i] - dy[i-1]
    if (diff < 0):
        changes.append(i)
    elif (diff > 0):
        changes.append(i)
        
del changes[0]
changes.append(len(dy))
n = len(changes) // 2
changes = np.array(changes).reshape((n, 2))

# %%
means = np.zeros((n, 3))
stds = np.zeros((n, 3))
for i in range(n):
    for j in range(3):
        ch = eval("ch%d"%(j + 1))
        fragment = ch[changes[i][0]:changes[i][1], 1]
        means[i, j] = fragment.mean()
        stds[i, j] = fragment.std()

# %%
reference = np.array([9.9, 14.9, 19.9, 24.9, 29.9, 34.9, 39.9, 44.9, 49.9])

fig, ax = plt.subplots(figsize = (8, 4.5))

for i in range(3):
    x = reference
    y = means[:, i]
    (m, b), pcov = regression(x, y)
    c = ax.errorbar(x, y, yerr = 0.4, fmt = "o", label = "Sensor %d"%(i + 1), ms = 4)[0].get_color()
    
    yy = m * x + b
    ax.plot(x, yy, "--", c = c)
    print(m, b)
    
    
ax.legend()
ax.set_ylabel("Voltaje (mV)")
ax.set_xlabel("Temperatura ($^\circ$C)")

fig.tight_layout()
plt.show()
# Out:
# 10.257054724036978 -12.189663112035936
# 10.303322602904469 -10.223256431756885
# 10.290071596278622 -8.39444281589243
